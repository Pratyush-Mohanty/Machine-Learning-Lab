# %%
from datetime import date


print("Name- Pratyush Mohanty")
print("Roll No-118CS0180")
print("Date- {}".format(date.today()))
print("Machine learning Lab 9")
# Out:
# Name- Pratyush Mohanty
# Roll No-118CS0180
# Date- 2021-11-16
# Machine learning Lab 9

# %% [markdown]
# # Design of a perceptron network to implement the logic functions.

# %% [markdown]
# Required Library Import

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Activation Function,Forward Propagation and Backward Propagation

# %% [markdown]
# sigmoid activation function was used for hidden layer and output

# %%
def sigmoid(z):
    z= 1/(1+np.exp(-z))
    return z

# Forward propagation
def forward_prop(w1,w2,x):
    z1 = np.dot(w1,x)
    a1 = sigmoid(z1)    
    z2 = np.dot(w2,a1)
    a2 = sigmoid(z2)
    return z1,a1,z2,a2

# Backward propagation
def back_prop(m,w1,w2,z1,a1,z2,a2,y):
    
    dz2 = a2-y
    dw2 = np.dot(dz2,a1.T)/m
    dz1 = np.dot(w2.T,dz2) * a1*(1-a1)
    dw1 = np.dot(dz1,x.T)/m
    dw1 = np.reshape(dw1,w1.shape)
    
    dw2 = np.reshape(dw2,w2.shape)    
    return dz2,dw2,dz1,dw1

# %% [markdown]
# # Neural network for 10000 iterations and observe the loss value

# %%
def nn(x,w1,w2):
    losses=[]
    iterations = 10000
    for i in range(iterations):
        z1,a1,z2,a2 = forward_prop(w1,w2,x)
        loss = -(1/m)*np.sum(y*np.log(a2)+(1-y)*np.log(1-a2))
        losses.append(loss)
        da2,dw2,dz1,dw1 = back_prop(m,w1,w2,z1,a1,z2,a2,y)
        w2 = w2-lr*dw2
        w1 = w1-lr*dw1

    # We plot losses to see how our network is doing
    plt.plot(losses,color="red")
    plt.xlabel("EPOCHS")
    plt.ylabel("Loss value")
    plt.grid(1)

# %% [markdown]
# # Option A

# %%
x=np.array([[0,0,1,1],[0,1,0,1]])
y=np.array([[0,0,0,1]])
# Number of inputs
n_x = 2
# Number of neurons in output layer
n_y = 1
# Number of neurons in hidden layer
n_h = 4
# Total training examples
m = x.shape[1]
# Learning rate
lr = 0.1
# Define random seed for consistent results
np.random.seed(2)
# Define weight matrices for neural network
w1 = np.random.rand(n_h,n_x)   # Weight matrix for hidden layer
w2 = np.random.rand(n_y,n_h)   # Weight matrix for output layer
# I didnt use bias units
# We will use this list to accumulate losses
#losses = []
nn(x,w1,w2)

# %% [markdown]
# # Option B

# %%
x=np.array([[0,0,1,1],[0,1,0,1]])
y=np.array([[0,1,1,1]])
# Number of inputs
n_x = 2
# Number of neurons in output layer
n_y = 1
# Number of neurons in hidden layer
n_h = 2
# Total training examples
m = x.shape[1]
# Learning rate
lr = 0.1
# Define random seed for consistent results
np.random.seed(2)
# Define weight matrices for neural network
w1 = np.random.rand(n_h,n_x)   # Weight matrix for hidden layer
w2 = np.random.rand(n_y,n_h)   # Weight matrix for output layer
nn(x,w1,w2)

# %% [markdown]
# # Option C

# %%
x=np.array([[0,0,1,1],[0,1,0,1]])
y=np.array([[1,0,0,0]])
# Number of inputs
n_x = 2
# Number of neurons in output layer
n_y = 1
# Number of neurons in hidden layer
n_h = 2
# Total training examples
m = x.shape[1]
# Learning rate
lr = 0.1
# Define random seed for consistent results
np.random.seed(2)
# Define weight matrices for neural network
w1 = np.random.rand(n_h,n_x)   # Weight matrix for hidden layer
w2 = np.random.rand(n_y,n_h)   # Weight matrix for output layer
nn(x,w1,w2)

# %% [markdown]
# # Option D

# %%
x=np.array([[2,1,-2,-1],[2,-2,2,1]])
y=np.array([[0,1,0,1]])
# Number of inputs
n_x = 2
# Number of neurons in output layer
n_y = 1
# Number of neurons in hidden layer
n_h = 2
# Total training examples
m = x.shape[1]
# Learning rate
lr = 0.1
# Define random seed for consistent results
np.random.seed(2)
# Define weight matrices for neural network
w1 = np.random.rand(n_h,n_x)   # Weight matrix for hidden layer
w2 = np.random.rand(n_y,n_h)   # Weight matrix for output layer
nn(x,w1,w2)

# %% [markdown]
# # Option E

# %%
x=np.array([[0,-2,-2,-2,0,2,2,2],[2,0,2,-2,-2,0,-2,2]])
y=np.array([[1,1,1,1,0,0,0,0]])
# Number of inputs
n_x = 2
# Number of neurons in output layer
n_y = 1
# Number of neurons in hidden layer
n_h = 2
# Total training examples
m = x.shape[1]
# Learning rate
lr = 0.1
# Define random seed for consistent results
np.random.seed(2)
# Define weight matrices for neural network
w1 = np.random.rand(n_h,n_x)   # Weight matrix for hidden layer
w2 = np.random.rand(n_y,n_h)   # Weight matrix for output layer
nn(x,w1,w2)

# %% [markdown]
# # Option F

# %%
x=np.array([[1,1],[-1,1],[-1,-1]])
y=np.array([[0,1]])
# Number of inputs
n_x = 3
# Number of neurons in output layer
n_y = 1
# Number of neurons in hidden layer
n_h = 6
# Total training examples
m = x.shape[1]
# Learning rate
lr = 0.1
# Define random seed for consistent results
np.random.seed(2)
# Define weight matrices for neural network
w1 = np.random.rand(n_h,n_x)   # Weight matrix for hidden layer
w2 = np.random.rand(n_y,n_h)   # Weight matrix for output layer
nn(x,w1,w2)
